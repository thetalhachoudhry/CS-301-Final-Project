# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
import pandas as pd

# %%
# Data can be downloaded at this location and should be uploaded into the google colab files section
# https://drive.google.com/file/d/1cIYx7i3dMytWbhYU--g1TUiIO9akIHHg/view?usp=sharing
df = pd.read_csv("Life Expectancy Data.csv")
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# create dist plot
fig, ax = plt.subplots(ncols=7, nrows=3, figsize=(20, 15),sharey=False,sharex=False)
index = 0
ax = ax.flatten()
for col, value in df.drop(columns=["Country"],axis=1).items():
    g1=sns.histplot(value, ax=ax[index])
    g1.set(ylabel=None)
    ax[index].xaxis.label.set_size(15)
    ax[index].tick_params(axis="x", labelsize=12)
    ax[index].tick_params(axis="y", labelsize=12)
    index += 1
plt.tight_layout(pad=0.5, w_pad=3, h_pad=5.0)

# %%
# create box plots
fig, ax = plt.subplots(ncols=5, nrows=4, figsize=(20,16))
index = 0
ax = ax.flatten()
for col, value in  df.drop(columns=["Country","Status"],axis=1).items():
    sns.boxplot(y=col, data=df, ax=ax[index])
    ax[index].set(xlabel=col,ylabel='',title='')
    ax[index].xaxis.label.set_size(15)
    ax[index].tick_params(axis="x", labelsize=14)
    ax[index].tick_params(axis="y", labelsize=14)
    index += 1
plt.tight_layout(pad=0.5, w_pad=3, h_pad=5.0)

# %%
df = pd.get_dummies(df, columns=['Status'],dtype=float)
df
# Out:
#           Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0     Afghanistan  2015              65.0            263.0             62
# 1     Afghanistan  2014              59.9            271.0             64
# 2     Afghanistan  2013              59.9            268.0             66
# 3     Afghanistan  2012              59.5            272.0             69
# 4     Afghanistan  2011              59.2            275.0             71
# ...           ...   ...               ...              ...            ...
# 2933     Zimbabwe  2004              44.3            723.0             27
# 2934     Zimbabwe  2003              44.5            715.0             26
# 2935     Zimbabwe  2002              44.8             73.0             25
# 2936     Zimbabwe  2001              45.3            686.0             25
# 2937     Zimbabwe  2000              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
import matplotlib.colors as clr
myColors = ("red","white","blue")
cmap1 = clr.LinearSegmentedColormap.from_list('Custom', myColors, len(myColors))
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
#mask[np.triu_indices_from(mask)]= True
plt.figure(figsize=(20,10))
sns.heatmap(corr,mask = mask, vmin = -1, vmax = 1, annot=True)
# Out:
# <Axes: >

# %%
# Adult Mortality, Alcohol, BMI, HIV/AIDS, GDP, income, schooling, development status, thinness 1-19
df = df[["Adult Mortality","Life expectancy ","Alcohol","GDP"," HIV/AIDS","Income composition of resources","Schooling","Status_Developed","Status_Developing"," thinness  1-19 years"," BMI "]]
df = df.dropna()
df
# Out:
#       Adult Mortality  Life expectancy   Alcohol         GDP   HIV/AIDS  \
# 0               263.0              65.0     0.01  584.259210        0.1
# 1               271.0              59.9     0.01  612.696514        0.1
# 2               268.0              59.9     0.01  631.744976        0.1
# 3               272.0              59.5     0.01  669.959000        0.1
# 4               275.0              59.2     0.01   63.537231        0.1
# ...               ...               ...      ...         ...        ...
# 2933            723.0              44.3     4.36  454.366654       33.6
# 2934            715.0              44.5     4.06  453.351155       36.7
# 2935             73.0              44.8     4.43   57.348340       39.8
# 2936            686.0              45.3     1.72  548.587312       42.1
# 2937            665.0              46.0     1.68  547.358878       43.5
#
#       Income composition of resources  Schooling  Status_Developed  \
# ...

# %% [markdown]
# #Models Used:
# #Multiple Linear Regression
# #Decision Trees

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pydot
from IPython.display import Image
from six import StringIO
from sklearn.tree import DecisionTreeRegressor, export_graphviz
plt.style.use('seaborn-white')
import warnings
warnings.filterwarnings('ignore')


# This function creates images of tree models using pydot
def print_tree(estimator, features, class_names=None, filled=True):
    tree = estimator
    names = features
    color = filled
    classn = class_names

    dot_data = StringIO()
    export_graphviz(estimator, out_file=dot_data, feature_names=features, class_names=classn, filled=filled)
    graph = pydot.graph_from_dot_data(dot_data.getvalue())
    return(graph)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, r2_score
from sklearn import metrics

# %%
x,y = df.drop(columns = ["Life expectancy "],axis=1),df['Life expectancy ']
x_train,x_test,y_train,y_test = train_test_split( x ,y )
treg = DecisionTreeRegressor(max_depth=4)
treg.fit(x_train,y_train)
y_pred = treg.predict(x_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R-squared:', r2_score(y_test, y_pred))
print("\n")
# Out:
# Mean Absolute Error: 2.58380725154973
# Mean Squared Error: 13.366842793673236
# Root Mean Squared Error: 3.656069309199873
# R-sqaured: 0.8688371247428789

# %%
graph, = print_tree(treg, features=x.columns)
Image(graph.create_png())

# %% [markdown]
# #Multiple Linear Regression

# %%
model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R-sqaured:', r2_score(y_test, y_pred))
print("\n")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (y_pred)")
plt.title("Actual vs. Predicted Values in Multiple Linear Regression")
plt.show()

residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0
plt.show()
# Out:
# Mean Absolute Error: 3.1173210283190875
# Mean Squared Error: 18.682813144063324
# Root Mean Squared Error: 4.322361986699324
# R-sqaured: 0.8166738752230451
